# %%
import pandas as pd
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)

# %% [markdown]
# #### Read the file 'DHAW2023-7-Pandas-assignment-NBA.xlsx'. I downloaded the excel from [nbastuffer.com](https://www.nbastuffer.com/2021-2022-nba-player-stats/) and I removed the first column and the first row.

# %%
df = pd.read_excel("DHAW2023-7-Pandas-assignment-NBA.xlsx")

# %% [markdown]
# #### Print the first five lines

# %%
df.head(5)
# Out:
#                   FULL NAME TEAM  POS    AGE  GP   MPG  MIN%Minutes PercentagePercentage of team minutes used by a player while he was on the floor  USG%Usage RateUsage rate, a.k.a., usage percentage is an estimate of the percentage of team plays used by a player while he was on the floor  TO%Turnover RateA metric that estimates the number of turnovers a player commits per 100 possessions  FTA    FT%  2PA    2P%  3PA    3P%  eFG%Effective Shooting PercentageWith eFG%, three-point shots made are worth 50% more than two-point shots made. eFG% Formula=(FGM+ (0.5 x 3PM))/FGA  TS%True Shooting PercentageTrue shooting percentage is a measure of shooting efficiency that takes into account field goals, 3-point field goals, and free throws.  PPGPointsPoints per game.  RPGReboundsRebounds per game.  TRB%Total Rebound PercentageTotal rebound percentage is estimated percentage of available rebounds grabbed by the player while the player is on the court.  APGAssistsAssists per game.  \
# 0          Precious Achiuwa  Tor    F  22.74   6  27.8                                               57.8                                                                                         18.2                                                                                                                                          13.8                                                      10  0.600   36  0.556   16  0.313                                              0.529                                                                                                                                                 0.541                                                                                                                                        10.2                            4.8                                               10.7                                                                                                                                   1.0
# 1              Steven Adams  Mem    C  28.91   7  16.2                                               33.8                                                                                         10.8                                                                                                                                          13.4                                                      11  0.545   21  0.429    0  0.000                                              0.429                                                                                                                                                 0.464                                                                                                                                         3.4                            6.4                                               20.9                                                                                                                                   2.1
# 2               Bam Adebayo  Mia  C-F  24.92  18  34.1                                               71.0                                                                                         17.9                                                                                                                                          15.4                                                      76  0.763  174  0.598    1  0.000                                              0.594                                                                                                                                                 0.638                                                                                                                                        14.8                            8.0                                               13.8                                                                                                                                   2.7
# 3  Nickeil Alexander-Walker  Uta    G  23.79   1   4.7                                                9.8                                                                                         24.4                                                                                                                                           0.0                                                       1  1.000    2  1.000    0  0.000                                              1.000                                                                                                                                                 1.025                                                                                                                                         5.0                            1.0                                               12.4                                                                                                                                   1.0
# 4             Grayson Allen  Mil    G  26.69  12  25.4                                               53.0                                                                                         13.6                                                                                                                                           9.4                                                      11  0.636   34  0.529   48  0.396                                              0.567                                                                                                                                                 0.576                                                                                                                                         8.3                            2.9                                                5.9                                                                                                                                   1.3
#
#    AST%Assist PercentageAssist percentage is an estimated percentage of teammate field goals a player assisted while the player is on the court  SPGStealsSteals per game.  BPGBlocksBlocks per game.  TOPGTurnoversTurnovers per game.  VIVersatility IndexVersatility index is a metric that measures a player’s ability to produce in points, assists, and rebounds. The average player will score around a five on the index, while top players score above 10  ORTGOffensive RatingIndividual offensive rating is the number of points produced by a player per 100 total individual possessions.  DRTGDefensive RatingIndividual defensive rating estimates how many points the player allowed per 100 possessions he individually faced while staying on the court.
# 0                                                5.7                                                                                                                  0.17                       0.83                              1.50                                                5.3                                                                                                                                                                                                                      103.3                                                                                                                               107.9
# 1                                               17.6                                                                                                                  0.14                       0.14                              0.57                                                8.8                                                                                                                                                                                                                      120.1                                                                                                                               100.4
# 2                                               12.6                                                                                                                  1.00                       0.72                              2.11                                                8.0                                                                                                                                                                                                                      119.8                                                                                                                               101.2
# 3                                               70.1                                                                                                                  1.00                       0.00                              0.00                                               14.6                                                                                                                                                                                                                      214.3                                                                                                                               100.3
# 4                                                7.2                                                                                                                  0.67                       0.33                              0.75                                                5.0                                                                                                                                                                                                                      112.0                                                                                                                               107.6

# %% [markdown]
# #### Get the name of the columns

# %%
df.columns
# Out:
# Index(['FULL NAME', 'TEAM', 'POS', 'AGE', 'GP', 'MPG', 'MIN%Minutes PercentagePercentage of team minutes used by a player while he was on the floor', 'USG%Usage RateUsage rate, a.k.a., usage percentage is an estimate of the percentage of team plays used by a player while he was on the floor', 'TO%Turnover RateA metric that estimates the number of turnovers a player commits per 100 possessions', 'FTA', 'FT%', '2PA', '2P%', '3PA', '3P%', 'eFG%Effective Shooting PercentageWith eFG%, three-point shots made are worth 50% more than two-point shots made. eFG% Formula=(FGM+ (0.5 x 3PM))/FGA', 'TS%True Shooting PercentageTrue shooting percentage is a measure of shooting efficiency that takes into account field goals, 3-point field goals, and free throws.', 'PPGPointsPoints per game.', 'RPGReboundsRebounds per game.', 'TRB%Total Rebound PercentageTotal rebound percentage is estimated percentage of available rebounds grabbed by the player while the player is on the court.',
#        'APGAssistsAssists per game.', 'AST%Assist PercentageAssist percentage is an estimated percentage of teammate field goals a player assisted while the player is on the court', 'SPGStealsSteals per game.', 'BPGBlocksBlocks per game.', 'TOPGTurnoversTurnovers per game.', 'VIVersatility IndexVersatility index is a metric that measures a player’s ability to produce in points, assists, and rebounds. The average player will score around a five on the index, while top players score above 10', 'ORTGOffensive RatingIndividual offensive rating is the number of points produced by a player per 100 total individual possessions.', 'DRTGDefensive RatingIndividual defensive rating estimates how many points the player allowed per 100 possessions he individually faced while staying on the court.'],
#       dtype='object')

# %% [markdown]
# #### Get the stats of "Giannis Antetokounmpo"

# %%
df[(df['FULL NAME'] == 'Giannis Antetokounmpo')]
# Out:
#                FULL NAME TEAM POS    AGE  GP   MPG  MIN%Minutes PercentagePercentage of team minutes used by a player while he was on the floor  USG%Usage RateUsage rate, a.k.a., usage percentage is an estimate of the percentage of team plays used by a player while he was on the floor  TO%Turnover RateA metric that estimates the number of turnovers a player commits per 100 possessions  FTA    FT%  2PA    2P%  3PA   3P%  eFG%Effective Shooting PercentageWith eFG%, three-point shots made are worth 50% more than two-point shots made. eFG% Formula=(FGM+ (0.5 x 3PM))/FGA  TS%True Shooting PercentageTrue shooting percentage is a measure of shooting efficiency that takes into account field goals, 3-point field goals, and free throws.  PPGPointsPoints per game.  RPGReboundsRebounds per game.  TRB%Total Rebound PercentageTotal rebound percentage is estimated percentage of available rebounds grabbed by the player while the player is on the court.  APGAssistsAssists per game.  \
# 7  Giannis Antetokounmpo  Mil   F  27.53  12  37.3                                               77.7                                                                                         38.5                                                                                                                                          13.6                                                     134  0.679  244  0.537   41  0.22                                              0.507                                                                                                                                                 0.552                                                                                                                                        31.7                           14.2                                               19.5                                                                                                                                   6.8
#
#    AST%Assist PercentageAssist percentage is an estimated percentage of teammate field goals a player assisted while the player is on the court  SPGStealsSteals per game.  BPGBlocksBlocks per game.  TOPGTurnoversTurnovers per game.  VIVersatility IndexVersatility index is a metric that measures a player’s ability to produce in points, assists, and rebounds. The average player will score around a five on the index, while top players score above 10  ORTGOffensive RatingIndividual offensive rating is the number of points produced by a player per 100 total individual possessions.  DRTGDefensive RatingIndividual defensive rating estimates how many points the player allowed per 100 possessions he individually faced while staying on the court.
# 7                                               37.0                                                                                                                  0.67                       1.33                               4.5                                               15.6                                                                                                                                                                                                                      107.9                                                                                                                                99.6

# %% [markdown]
# #### How many players are over 30 years old?

# %%
overthirty = df[(df['AGE'] > 30)]
overth = overthirty.shape[0]
print(f"There are {overth} players over thirty.")
# Out:
# There are 58 players over thirty.

# %%
# another way to do this
(df['AGE'] >30).value_counts()
# value counts w/o parens makes a list of true and false
# value counts w/ parens adds the trues and falses
# Out:
# False    159
# True      58
# Name: AGE, dtype: int64

# %% [markdown]
# #### How many players of Milwaukee Bucks are in this DataFrame?

# %%
bucks = df[(df['TEAM'] == "Mil")]
bucks.shape[0]
print(f"There are {bucks.shape[0]} Bucks players in this data.")
# Out:
# There are 15 Bucks players in this data.

# %% [markdown]
# #### How many players of Milwaukee Bucks are over 30 years old?

# %%
bucksoverthiry = df[(df['TEAM'] == "Mil") & (df['AGE'] > 30)]
bucksoverthiry.shape[0]
print(f"There are {bucksoverthiry.shape[0]} Bucks players over thirty years old.")
# Out:
# There are 6 Bucks players over thirty years old.

# %% [markdown]
# #### Which players of Milwaukee Bucks were shooting with average over 50% in either 2P% or 3P%

# %%
buckshot = bucks[(bucks['2P%'] > .5) | (bucks['3P%'] > .5)]
buckshot[['FULL NAME', '2P%', '3P%']]
# Out:
#                   FULL NAME    2P%    3P%
# 4             Grayson Allen  0.529  0.396
# 7     Giannis Antetokounmpo  0.537  0.220
# 8    Thanasis Antetokounmpo  0.667  0.000
# 51          Pat Connaughton  0.708  0.391
# 123             Brook Lopez  0.595  0.214
# 200            Luca Vildoza  1.000  0.200

# %%
# No Bucks shot threes for more than 50%
buckthrees = bucks.set_index('3P%')
buckthrees.sort_index(ascending=False)
# Out:
#                     FULL NAME TEAM POS    AGE  GP   MPG  MIN%Minutes PercentagePercentage of team minutes used by a player while he was on the floor  USG%Usage RateUsage rate, a.k.a., usage percentage is an estimate of the percentage of team plays used by a player while he was on the floor  TO%Turnover RateA metric that estimates the number of turnovers a player commits per 100 possessions  FTA    FT%  2PA    2P%  3PA  eFG%Effective Shooting PercentageWith eFG%, three-point shots made are worth 50% more than two-point shots made. eFG% Formula=(FGM+ (0.5 x 3PM))/FGA  TS%True Shooting PercentageTrue shooting percentage is a measure of shooting efficiency that takes into account field goals, 3-point field goals, and free throws.  PPGPointsPoints per game.  RPGReboundsRebounds per game.  TRB%Total Rebound PercentageTotal rebound percentage is estimated percentage of available rebounds grabbed by the player while the player is on the court.  APGAssistsAssists per game.  \
# 3P%
# 0.500             George Hill  Mil   G  36.12   5  15.3                                               31.8                                                                                          3.9                                                                                                                                          14.5                                                       2  1.000    3  0.000    2                                              0.300                                                                                                                                                 0.425                                                                                                                                         1.0                            1.2                                                4.0                                                                                                                                   0.6
# 0.429            Jevon Carter  Mil   G  26.76  11  11.4                                               23.8                                                                                          8.9                                                                                                                                          23.2                                                       2  1.000   12  0.500    7                                              0.553                                                                                                                                                 0.578                                                                                                                                         2.1                            1.5                                                6.5                                                                                                                                   0.9
# 0.429         Khris Middleton  Mil   F  30.85   2  35.8                                               74.5                                                                                         22.0                                                                                                                                          30.3                                                       3  1.000   10  0.400   14                                              0.542                                                                                                                                                 0.573                                                                                                                                        14.5                            5.0                                                7.2                                                                                                                                   7.0
# 0.400         Wesley Matthews  Mil   G  35.67  12  28.7                                               59.8                                                                                          9.3                                                                                                                                           8.1                                                       9  0.667   19  0.368   45                                              0.531                                                                                                                                                 0.544                                                                                                                                         6.2                            3.1                                                5.5                                                                                                                                   1.2
# 0.396           Grayson Allen  Mil   G  26.69  12  25.4                                               53.0                                                                                         13.6                                                                                                                                           9.4                                                      11  0.636   34  0.529   48                                              0.567                                                                                                                                                 0.576                                                                                                                                         8.3                            2.9                                                5.9                                                                                                                                   1.3
# 0.391         Pat Connaughton  Mil   G  29.44  12  26.5                                               55.2                                                                                         13.2                                                                                                                                           7.2                                                       5  1.000   24  0.708   64                                              0.619                                                                                                                                                 0.632                                                                                                                                         9.5                            4.3                                                8.2                                                                                                                                   0.9
# 0.316            Jrue Holiday  Mil   G  32.01  12  38.6                                               80.4                                                                                         26.4                                                                                                                                          12.0                                                      31  0.839  156  0.410   79                                              0.432                                                                                                                                                 0.461                                                                                                                                        19.1                            5.6                                                7.4                                                                                                                                   6.5
# 0.298            Bobby Portis  Mil   F  27.35  12  24.8                                               51.6                                                                                         20.5                                                                                                                                          11.4                                                      22  0.773   68  0.500   47                                              0.478                                                                                                                                                 0.509                                                                                                                                        10.6                           10.0                                               20.7                                                                                                                                   0.8
# 0.220   Giannis Antetokounmpo  Mil   F  27.53  12  37.3                                               77.7                                                                                         38.5                                                                                                                                          13.6                                                     134  0.679  244  0.537   41                                              0.507                                                                                                                                                 0.552                                                                                                                                        31.7                           14.2                                               19.5                                                                                                                                   6.8
# 0.214             Brook Lopez  Mil   C  34.21  12  27.7                                               57.6                                                                                         16.1                                                                                                                                           8.9                                                      23  0.913   74  0.595   28                                              0.520                                                                                                                                                 0.566                                                                                                                                        10.6                            5.9                                               11.0                                                                                                                                   0.7
# 0.200            Luca Vildoza  Mil   G  20.00   7   2.4                                                5.0                                                                                         15.4                                                                                                                                           0.0                                                       0  0.000    1  1.000    5                                              0.417                                                                                                                                                 0.417                                                                                                                                         0.7                            0.3                                                6.1                                                                                                                                   0.6
# 0.000  Thanasis Antetokounmpo  Mil   F  29.91   8   2.6                                                5.3                                                                                          9.2                                                                                                                                           0.0                                                       3  0.333    3  0.667    0                                              0.667                                                                                                                                                 0.579                                                                                                                                         0.6                            0.5                                               10.0                                                                                                                                   0.1
# 0.000             Serge Ibaka  Mil   F  32.75   6   3.7                                                7.7                                                                                         37.0                                                                                                                                          10.6                                                       2  0.500   13  0.308    3                                              0.250                                                                                                                                                 0.267                                                                                                                                         1.5                            1.7                                               23.2                                                                                                                                   0.0
# 0.000            Jordan Nwora  Mil   F  23.77   8   2.5                                                5.2                                                                                         21.4                                                                                                                                           0.0                                                       2  0.000    5  0.400    4                                              0.222                                                                                                                                                 0.202                                                                                                                                         0.5                            0.4                                                7.7                                                                                                                                   0.3
# 0.000           Rayjon Tucker  Mil   G  24.73   8   2.4                                                4.9                                                                                          6.9                                                                                                                                           0.0                                                       0  0.000    2  0.500    1                                              0.333                                                                                                                                                 0.333                                                                                                                                         0.3                            0.4                                                8.2                                                                                                                                   0.0
#
#        AST%Assist PercentageAssist percentage is an estimated percentage of teammate field goals a player assisted while the player is on the court  SPGStealsSteals per game.  BPGBlocksBlocks per game.  TOPGTurnoversTurnovers per game.  VIVersatility IndexVersatility index is a metric that measures a player’s ability to produce in points, assists, and rebounds. The average player will score around a five on the index, while top players score above 10  ORTGOffensive RatingIndividual offensive rating is the number of points produced by a player per 100 total individual possessions.  DRTGDefensive RatingIndividual defensive rating estimates how many points the player allowed per 100 possessions he individually faced while staying on the court.
# 3P%
# 0.500                                                5.0                                                                                                                  0.00                       0.00                              0.20                                                2.3                                                                                                                                                                                                                      103.7                                                                                                                               103.7
# 0.429                                               10.9                                                                                                                  0.73                       0.00                              0.55                                                5.0                                                                                                                                                                                                                      107.0                                                                                                                               102.5
# 0.429                                               29.6                                                                                                                  1.50                       0.00                              5.50                                                8.9                                                                                                                                                                                                                       95.3                                                                                                                               104.6
# 0.400                                                5.6                                                                                                                  0.75                       0.25                              0.50                                                4.0                                                                                                                                                                                                                      114.2                                                                                                                               107.3
# 0.396                                                7.2                                                                                                                  0.67                       0.33                              0.75                                                5.0                                                                                                                                                                                                                      112.0                                                                                                                               107.6
# 0.391                                                5.2                                                                                                                  0.42                       0.33                              0.58                                                5.0                                                                                                                                                                                                                      120.4                                                                                                                               109.9
# 0.316                                               27.6                                                                                                                  1.75                       0.58                              2.83                                                9.2                                                                                                                                                                                                                       97.7                                                                                                                               107.0
# 0.298                                                4.7                                                                                                                  0.42                       0.25                              1.33                                                7.1                                                                                                                                                                                                                      103.0                                                                                                                               100.7
# 0.220                                               37.0                                                                                                                  0.67                       1.33                              4.50                                               15.6                                                                                                                                                                                                                      107.9                                                                                                                                99.6
# 0.214                                                3.7                                                                                                                  0.50                       1.50                              0.92                                                5.1                                                                                                                                                                                                                      117.3                                                                                                                               104.4
# 0.200                                               34.6                                                                                                                  0.29                       0.00                              0.00                                                8.4                                                                                                                                                                                                                        NaN                                                                                                                                 NaN
# 0.000                                                7.0                                                                                                                  0.13                       0.00                              0.00                                                4.8                                                                                                                                                                                                                        NaN                                                                                                                                 NaN
# 0.000                                                0.0                                                                                                                  0.00                       0.00                              0.33                                                0.0                                                                                                                                                                                                                        NaN                                                                                                                                 NaN
# 0.000                                               14.2                                                                                                                  0.00                       0.00                              0.00                                                6.3                                                                                                                                                                                                                        NaN                                                                                                                                 NaN
# 0.000                                                0.0                                                                                                                  0.00                       0.00                              0.00                                                0.0                                                                                                                                                                                                                        NaN                                                                                                                                 NaN

# %% [markdown]
# #### Get Milwaukee Bucks' average free throws (FT%)

# %%
bucksftavg = (bucks['FT%'].mean())*100
print(f"The Buck's free throw average is {bucksftavg:.2f}%")

# also could do:
# bucks['FT%'].describe()
# Out:
# The Buck's free throw average is 62.27%

# %%
# can do it from the full frame without making the cut, and put ['FT%'] as the filter after
df[(df['TEAM'] == 'Mil')]['FT%'].mean()
# Out:
# 0.6226666666666667

# %% [markdown]
# #### Get the average free throws per team
# Hint: pandas has a method for finding the mean.

# %%
sortedfreethrowavg = df.groupby(["TEAM"]).mean(numeric_only=True).sort_values('FT%', ascending = False)['FT%']
sortedfreethrowavg
# Out:
# TEAM
# Dal    0.781500
# Mem    0.725231
# Bos    0.689267
# Gol    0.687500
# Uta    0.670333
# Nor    0.663500
# Mia    0.628786
# Den    0.628385
# Mil    0.622667
# Min    0.622231
# Pho    0.595643
# Atl    0.578929
# Tor    0.560133
# Chi    0.524500
# Bro    0.512000
# Phi    0.481400
# Name: FT%, dtype: float64

# %%
# we don't need to create a new frame. can just:
df.groupby(["TEAM"]).mean(numeric_only=True).sort_values('FT%', ascending = False)['FT%']
# Out:
# TEAM
# Dal    0.781500
# Mem    0.725231
# Bos    0.689267
# Gol    0.687500
# Uta    0.670333
# Nor    0.663500
# Mia    0.628786
# Den    0.628385
# Mil    0.622667
# Min    0.622231
# Pho    0.595643
# Atl    0.578929
# Tor    0.560133
# Chi    0.524500
# Bro    0.512000
# Phi    0.481400
# Name: FT%, dtype: float64

# %% [markdown]
# #### Guess the result of the next code: True or False?

# %%
simpsons = pd.Series(
['Homer', 'Marge', 'Bart', 'Lisa', 'Maggie'])
print('Bart' in simpsons)
# Out:
# False

# %%
simpsons = pd.Series(
['Homer', 'Marge', 'Bart', 'Lisa', 'Maggie'])
print('Bart' in simpsons.values)
# Out:
# True

# %% [markdown]
# #### Round in pandas. `round()` function is used to round a DataFrame to a variable number of decimal places. Yet, run the cell below to see a weird behavior.

# %%
s = pd.Series([-2.5, -1.5, -0.5, 0.5, 1.5, 2.5])
print(s.round())
# Out:
# 0   -2.0
# 1   -2.0
# 2   -0.0
# 3    0.0
# 4    2.0
# 5    2.0
# dtype: float64

# %% [markdown]
# This is called bankers’ rounding. Odd numbers are rounded up, even numbers are rounded down.

# %% [markdown]
# #### Correct the mistake in the following cell to get numbers larger than two and small than five

# %%
nums = pd.Series([1, 2, 3, 4, 5, 6])
# print(nums[nums > 2 and nums < 5])
for i in nums.values :
    if i < 2 or i > 5:
        print(i)

# I know you can do this without iterating, but I can't figure out how
# Out:
# 1
# 6

# %% [markdown]
# #### Change the df in order to reflect an 20% increase in the prices.

# %%
df = pd.DataFrame([
['T-shirt', 70],
['Pants', 80],
['Coat', 250],
['Shirt', 95]], columns=['item', 'price'])

# %%
df['newPrice'] = df['price']*1.2
df['price'] = df['newPrice']
df = df.drop(columns=['newPrice'])
df
# Out:
#       item  price
# 0  T-shirt  100.8
# 1    Pants  115.2
# 2     Coat  360.0
# 3    Shirt  136.8

# %% [markdown]
# #### Change the df below so it reflects a 35% increase in the price of the vegetables and a 25% decrease in the price of fruits.

# %%
df = pd.DataFrame([
['Carrots', 'vegetable', 6],
['Apple', 'fruit', 5],
['Banana', 'fruit', 4],
['Spinach', 'vegetable', 2]], columns=['item', 'type', 'price'])

# %%
# this way will be depreciated, I think?
df.loc[df['type'] == "vegetable", 'price'] =df['price']*1.35
df.loc[df['type'] == "fruit", 'price'] =df['price']*.75
df
# Out:
#       item       type  price
# 0  Carrots  vegetable   8.10
# 1    Apple      fruit   3.75
# 2   Banana      fruit   3.00
# 3  Spinach  vegetable   2.70

# %%
# Can also do:
df.loc[df['type'] == "vegetable", 'price'] =df.loc[df['type'] == "vegetable", 'price']*1.35
df.loc[df['type'] == "fruit", 'price'] =df.loc[df['type'] == "fruit", 'price']*0.75
df
# Out:
#       item       type  price
# 0  Carrots  vegetable   8.10
# 1    Apple      fruit   3.75
# 2   Banana      fruit   3.00
# 3  Spinach  vegetable   2.70

# %%
# Or even
df.loc[df['type'] == "vegetable", 'price'] *=1.35
df.loc[df['type'] == "fruit", 'price'] *=0.75
df
# Out:
#       item       type  price
# 0  Carrots  vegetable   8.10
# 1    Apple      fruit   3.75
# 2   Banana      fruit   3.00
# 3  Spinach  vegetable   2.70

# %% [markdown]
# #### There is a DataFrame with products. If the products are going to turn bad soon, their condition is described as False. Else, their condition is True. Create a new df that gives a 40% discount if the product might turn bad and 15% increase if they are still in good condition.

# %%
df = pd.DataFrame([
['Egg', False, 6],
['Watermelon', True, 5],
['Milk', False, 4],
['Water', True, 2]], columns=['item', 'condition', 'price'])

# %%
df.loc[df['condition'] == True, 'price'] = df['price']*1.15
df.loc[df['condition'] == False, 'price'] = df['price']*.6 
df
# Out:
#          item  condition  price
# 0         Egg      False   3.60
# 1  Watermelon       True   5.75
# 2        Milk      False   2.40
# 3       Water       True   2.30

# %%
df.loc[df['condition'] == True, 'price'] *= 1.15
df.loc[df['condition'] == False, 'price'] *= 0.6 
df
# Out:
#          item  condition  price
# 0         Egg      False   3.60
# 1  Watermelon       True   5.75
# 2        Milk      False   2.40
# 3       Water       True   2.30

# %%
# remember, df.loc['column'] == 'searchterm' 
#     finds the entire row the value in the column 'column' is 'searchterm'
# remember, df.loc['column', 'get this value'] == 'searchterm' 
#     finds the 'get this value' where the value in the column 'column' is 'searchterm'
