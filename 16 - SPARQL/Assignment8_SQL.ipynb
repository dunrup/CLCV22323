# %% [markdown]
# SQL query:
#
# Create an ordered list with the city of each province with the most monuments, along with the counts of the monuments.
#
# Based on Hanson, J. W. (2016) Cities Database (OXREP databases) DOI: https://doi.org/10.5287/bodleian:eqapevAn8

# %%
import pandas as pd
import sqlite3

# %% [markdown]
# # use pandas to create count of monuments for each location

# %%
# first, I'm going to add a new 'monumentcount' column to the dataframes. 

# Read the excel as pandas DataFrame, first for the cities sheet then for the monuments sheet
cities_df = pd.read_excel('Hanson2016_CitiesDatabase_OxREP.xlsx', sheet_name='cities')
monuments_df = pd.read_excel('Hanson2016_CitiesDatabase_OxREP.xlsx', sheet_name='monuments')

# %%
cities_df.head(1)
# Out:
#              id ancient_toponym modern_toponym province country  \
# 0  Hanson2016_1            Abae       Kalapodi   Achaea  Greece
#
#   barrington_atlas_rank barrington_atlas_reference  start_date  end_date  \
# 0                4 or 5                      55 D3        -600       NaN
#
#    longitude   latitude                                select_bibliography
# 0  22.933333  38.583333  BNP; Hansen 2006; Hansen and Nielsen 2004; PEC...

# %%
# # this counts how many times each id in the cities sheet shows up in the monuments sheet
# for ids in cities_df['id']:
#     print(f"{ids}: {monuments_df[(monuments_df['id'] == ids)].shape[0]}")
    
# run this to check answers below

# %%
# turns the above into a dictionary of ids and monument counts
MonCount = {}
for ids in cities_df['id']:
    MonCount.update({ids: monuments_df[(monuments_df['id'] == ids)].shape[0]})

# %%
# first, add a new column to the cities sheet with a 'monument count' variable. 
# Then, set the new column's values with the map function and the dictionary we made above
cities_df['MonumentCount'] = cities_df['id'].map(MonCount)

# %%
# # tada! now we have a monument count value
cities_df[['id','MonumentCount']]
# Out:
#                    id  MonumentCount
# 0        Hanson2016_1              5
# 1        Hanson2016_2              3
# 2        Hanson2016_3              7
# 3        Hanson2016_4              8
# 4        Hanson2016_5              8
# ...               ...            ...
# 1383  Hanson2016_1384             11
# 1384  Hanson2016_1385             12
# 1385  Hanson2016_1386              6
# 1386  Hanson2016_1387              9
# 1387  Hanson2016_1388              4
#
# [1388 rows x 2 columns]

# %% [markdown]
# a different way to do this, by grouping the monument sheet rather than counting thru it. probably easier; same result

# %%
# # This line resets the memory.
# connection = sqlite3.connect(":memory:")

# # Read the excel as pandas DataFrame, first for the cities sheet then for the monuments sheet
# cities_df = pd.read_excel('Hanson2016_CitiesDatabase_OxREP.xlsx', sheet_name='cities')
# monuments_df = pd.read_excel('Hanson2016_CitiesDatabase_OxREP.xlsx', sheet_name='monuments')

# %%
# # groups monument sheet by id
# monsgrouped = monuments_df.groupby("id")

# %%
# gets the count of monuments for each id
# monsgrouped['structure'].count()

# %%
# # assigns a new column in cities_df based on the monument counts
# cities_df['MonumentCount'] = cities_df['id'].map(monsgrouped['structure'].count())

# %%
# # tada! now we have a monument count value
# cities_df[['id','MonumentCount']]

# %% [markdown]
# .

# %%
# sorting by mon count
cities_df[['id','ancient_toponym','province','MonumentCount']].sort_values('MonumentCount', ascending=False)
# Out:
#                  id   ancient_toponym                        province  \
# 991  Hanson2016_992              Roma            Italia (VII Etruria)
# 13    Hanson2016_14           Athenae                          Achaea
# 25    Hanson2016_26         Corinthia                          Achaea
# 304  Hanson2016_305          Pergamum                            Asia
# 179  Hanson2016_180      Lepcis Magna            Africa Proconsularis
# ..              ...               ...                             ...
# 539  Hanson2016_540  Novae (Dalmatia)                        Dalmatia
# 198  Hanson2016_199           Tacapae            Africa Proconsularis
# 915  Hanson2016_916          Pausulae              Italia (V Picenum)
# 914  Hanson2016_915            Numana              Italia (V Picenum)
# 809  Hanson2016_810           Ulubrae  Italia (I Latium and Campania)
#
#      MonumentCount
# 991            236
# 13             107
# 25              56
# 304             50
# 179             46
# ..             ...
# 539              0
# 198              0
# 915              0
# 914              0
# 809              0
#
# [1388 rows x 4 columns]

# %% [markdown]
# # Back to sql

# %%
# # This line resets the memory.
connection = sqlite3.connect(":memory:")


# Turn the DataFrames to SQLs
cities_df.to_sql('cities', con = connection, index = False)
monuments_df.to_sql('mons', con = connection, index = False)
# Out:
# 9471

# %%
pd.read_sql("""
SELECT id, province, MonumentCount
FROM cities
ORDER BY MonumentCount DESC
""", connection)
# Out:
#                    id              province  MonumentCount
# 0      Hanson2016_992  Italia (VII Etruria)            236
# 1       Hanson2016_14                Achaea            107
# 2       Hanson2016_26                Achaea             56
# 3      Hanson2016_305                  Asia             50
# 4      Hanson2016_180  Africa Proconsularis             46
# ...               ...                   ...            ...
# 1383  Hanson2016_1357       Syria Palestina              0
# 1384  Hanson2016_1360       Syria Palestina              0
# 1385  Hanson2016_1372               Thracia              0
# 1386  Hanson2016_1377               Thracia              0
# 1387  Hanson2016_1379               Thracia              0
#
# [1388 rows x 3 columns]

# %%
pd.read_sql("""
SELECT id as id, ancient_toponym as name, province AS province,
MAX(MonumentCount) AS topmons
FROM cities
GROUP BY province
ORDER BY topmons DESC
""", connection)
# Out:
#                  id                                    name  \
# 0    Hanson2016_992                                    Roma
# 1     Hanson2016_14                                 Athenae
# 2    Hanson2016_305                                Pergamum
# 3    Hanson2016_180                            Lepcis Magna
# 4   Hanson2016_1258                               Thamugadi
# 5    Hanson2016_481                                  Cyrene
# 6    Hanson2016_788                                   Ostia
# 7   Hanson2016_1375                               Byzantium
# 8   Hanson2016_1324                       Antiochia (Syria)
# 9    Hanson2016_658                                  Vienna
# 10  Hanson2016_1320                               Syracusae
# 11   Hanson2016_110                   Alexandria (Aegyptus)
# 12   Hanson2016_620                                Lugdunum
# 13  Hanson2016_1176                                     Iol
# 14   Hanson2016_714  Lucus Augusti (Hispania Tarraconensis)
# 15   Hanson2016_500                           Sarmizegetusa
# 16  Hanson2016_1128                                   Perge
# 17  Hanson2016_1077                         Augusta Emerita
# 18   Hanson2016_861                                 Paestum
# 19   Hanson2016_237                                  Gerasa
# 20  Hanson2016_1349                        Aelia Capitolina
# 21   Hanson2016_668                         Augusta Raurica
# 22   Hanson2016_336                                 Corduba
# 23  Hanson2016_1203                               Volubilis
# 24  Hanson2016_1161                                  Thasos
# 25   Hanson2016_842                                Tarentum
# 26  Hanson2016_1045                                Aquileia
# 27   Hanson2016_952                               Spoletium
# 28   Hanson2016_465                                 Caralis
# 29   Hanson2016_580                      Augusta Ambianorum
# 30  Hanson2016_1022                                 Ravenna
# 31   Hanson2016_547                                  Salona
# 32   Hanson2016_435                               Castabala
# 33   Hanson2016_412       Antiochia (Cappadocia et Galatia)
# 34   Hanson2016_385                                 Calleva
# 35  Hanson2016_1267                                Aquincum
# 36  Hanson2016_1207                                 Histria
# 37   Hanson2016_897                                Saepinum
# 38   Hanson2016_572           Mediolanum (Gallia Aquitania)
# 39   Hanson2016_379                               Nicomedia
# 40   Hanson2016_227                               Cemelenum
# 41  Hanson2016_1235                                Poetovio
# 42  Hanson2016_1224                                   Scupi
# 43   Hanson2016_906                                 Asculum
# 44   Hanson2016_226                           Forum Claudii
# 45  Hanson2016_1282                                 Savaria
# 46  Hanson2016_1072    Mediolanum (Italia (XI Transpadana))
# 47  Hanson2016_1290                              Cambodunum
# 48   Hanson2016_660                   Colonia Agrippinensis
# 49  Hanson2016_1030                     Augusta Bagiennorum
# 50   Hanson2016_224                                 Segusio
#
#                                 province  topmons
# 0                   Italia (VII Etruria)      236
# 1                                 Achaea      107
# 2                                   Asia       50
# 3                   Africa Proconsularis       46
# 4                                Numidia       40
# 5                     Creta et Cyrenaica       38
# 6         Italia (I Latium and Campania)       37
# 7                                Thracia       36
# 8                                  Syria       33
# 9                     Gallia Narbonensis       32
# 10                               Silicia       30
# 11                              Aegyptus       30
# 12                    Gallia Lugdunensis       26
# 13               Mauretania Caesariensis       25
# 14                Hispania Tarraconensis       25
# 15                                 Dacia       25
# 16                    Lycia et Pamphylia       24
# 17                             Lusitania       24
# 18        Italia (III Lucania et Brutii)       24
# 19                                Arabia       24
# 20                       Syria Palestina       23
# 21                     Germania Superior       22
# 22                               Baetica       22
# 23                  Mauretania Tingitana       21
# 24                             Macedonia       21
# 25        Italia (II Apulia et Calabria)       19
# 26         Italia (X Venetia et Histria)       18
# 27  Italia (VI Umbria and Ager Gallicus)       18
# 28                   Corsica et Sardinia       18
# 29                        Gallia Belgica       17
# 30                 Italia (VIII Aemilia)       16
# 31                              Dalmatia       16
# 32                     Cilicia et Cyprus       16
# 33                 Cappadocia et Galatia       16
# 34                             Britannia       16
# 35                     Pannonia Inferior       15
# 36                       Moesia Inferior       15
# 37                   Italia (IV Samnium)       15
# 38                      Gallia Aquitania       15
# 39                    Bithynia et Pontus       14
# 40                       Alpes Maritimae       13
# 41                               Noricum       12
# 42                       Moesia Superior       12
# 43                    Italia (V Picenum)       12
# 44              Alpes Graiae et Poeninae       12
# 45                     Pannonia Superior       11
# 46               Italia (XI Transpadana)       11
# 47                                Raetia       10
# 48                     Germania Inferior       10
# 49                   Italia (IX Liguria)        9
# 50                         Alpes Cottiae        7
